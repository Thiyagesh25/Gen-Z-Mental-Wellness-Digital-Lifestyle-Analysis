# %%
# Gen Z Mental Wellness & Digital Lifestyle Patterns
## Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import statistics as stats

# %%
df = pd.read_csv(r"C:\Users\god\Downloads\genz_mental_wellness_synthetic_dataset.csv")

# %%
df.head()
# Out:
#    Age  Gender   Country Student_Working_Status  Daily_Social_Media_Hours  \
# 0   24    Male    Canada                Working                      4.81
# 1   21    Male       USA                Student                      4.16
# 2   25    Male  Pakistan                Student                      3.07
# 3   22  Female  Pakistan                Student                      4.41
# 4   24    Male  Pakistan                Student                      2.97
#
#    Screen_Time_Hours  Night_Scrolling_Frequency  Online_Gaming_Hours  \
# 0               6.93                       2.61                 2.07
# 1               7.94                       1.85                 3.58
# 2               7.45                       2.96                 2.85
# 3               7.34                       4.51                 3.37
# 4               5.76                       2.36                 1.77
#
#   Content_Type_Preference  Exercise_Frequency_per_Week  ...  \
# ...

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female', 'Non-binary'], dtype=object)

# %%
df['Burnout_Risk'].unique()
# Out:
# array(['Medium', 'High', 'Low'], dtype=object)

# %%
df["Wellbeing_Index"].mean()
# Out:
# np.float64(3.8702129999999997)

# %%
df["Anxiety_Score"].mean()
# Out:
# np.float64(4.747555999999999)

# %%
df["Screen_Time_Hours"].mean()
# Out:
# np.float64(7.016991)

# %%
#Average sleep hours
df["Daily_Sleep_Hours"].mean()
# Out:
# np.float64(6.512031)

# %%
#Average exercise frequency
df["Exercise_Frequency_per_Week"].mean()
# Out:
# np.float64(2.994855)

# %%
#Corr Between Screen_Time_Hours & Anxiety_Score
df[["Screen_Time_Hours","Anxiety_Score"]].corr()
# Out:
#                    Screen_Time_Hours  Anxiety_Score
# Screen_Time_Hours           1.000000       0.099619
# Anxiety_Score               0.099619       1.000000

# %%
#Corr Between Daily_Sleep_Hours & Wellbeing_Index
df[["Daily_Sleep_Hours","Wellbeing_Index"]].corr()
# Out:
#                    Daily_Sleep_Hours  Wellbeing_Index
# Daily_Sleep_Hours           1.000000         0.701866
# Wellbeing_Index             0.701866         1.000000

# %%
#Groupby Average wellbeing by Burnout level
df.groupby("Burnout_Risk")["Wellbeing_Index"].mean()
# Out:
# Burnout_Risk
# High      2.952829
# Low       7.348594
# Medium    4.908087
# Name: Wellbeing_Index, dtype: float64

# %%
import matplotlib.pyplot as plt

df.groupby("Burnout_Risk")["Wellbeing_Index"].mean().plot(kind="bar")
plt.title("Average Wellbeing by Burnout Risk")
plt.ylabel("Average Wellbeing Index")
plt.show()

# %%
#Gender vs Anxiety
df.groupby("Gender")["Anxiety_Score"].mean()
# Out:
# Gender
# Female        4.753200
# Male          4.740240
# Non-binary    4.755761
# Name: Anxiety_Score, dtype: float64

# %%
#Corr Between Exercise vs Wellbeing
df[["Exercise_Frequency_per_Week","Wellbeing_Index"]].corr()
# Out:
#                              Exercise_Frequency_per_Week  Wellbeing_Index
# Exercise_Frequency_per_Week                     1.000000         0.180385
# Wellbeing_Index                                 0.180385         1.000000
